# %%
from Univariate import Univariate

# %%
import pandas as pd
dataset=pd.read_csv("Placement.csv") ## We used dataset as a input into multiple function , so we using this command in here

# %%
obj=Univariate()  ## assigning Class def into new instance called obj

# %%
qual,quan=obj.QuanQual(dataset) ## in this function we using return , assigning return value into variable , so we can use this variable for other function input .

# %%
print(quan,qual) ## using print we are displaying variable output
# Out:
# ['sl_no', 'ssc_p', 'hsc_p', 'degree_p', 'etest_p', 'mba_p', 'salary'] ['gender', 'ssc_b', 'hsc_b', 'hsc_s', 'degree_t', 'workex', 'specialisation', 'status']

# %%
obj.freqtab("hsc_p",dataset)
# Out:
#     Unique  Frequency  Relative    Cumsum
# 0    63.00         14  0.135922  0.135922
# 1    62.00         12  0.116505  0.252427
# 2    67.00          9  0.087379  0.339806
# 3    60.00          9  0.087379  0.427184
# 4    64.00          8  0.077670  0.504854
# ..     ...        ...       ...       ...
# 92   83.83          1  0.009709  2.048544
# 93   70.40          1  0.009709  2.058252
# 94   90.90          1  0.009709  2.067961
# 95   89.83          1  0.009709  2.077670
# 96   42.00          1  0.009709  2.087379
#
# [97 rows x 4 columns]

# %%
descriptive=obj.descriptive(quan,dataset)  # quan - since we already get the return value into variable here , so we can use that variable as a input here .

# %%
print(descriptive)
# Out:
#           sl_no      ssc_p      hsc_p   degree_p    etest_p      mba_p  \
# Mean      108.0  67.303395  66.333163  66.370186  72.100558  62.278186
# Median    108.0       67.0       65.0       66.0       71.0       62.0
# Mode          1       62.0       63.0       65.0       60.0       56.7
# Q1:25%     54.5       60.6       60.9       61.0       60.0     57.945
# Q2:50%    108.0       67.0       65.0       66.0       71.0       62.0
# Q3:75%    161.5       75.7       73.0       72.0       83.5     66.255
# 99%      212.86       87.0      91.86      83.86       97.0    76.1142
# Q4:100%   215.0       89.4       97.7       91.0       98.0      77.89
# IQR       107.0       15.1       12.1       11.0       23.5       8.31
# 1.5Rule   160.5      22.65      18.15       16.5      35.25     12.465
# Lesser   -106.0      37.95      42.75       44.5      24.75      45.48
# Greater   322.0      98.35      91.15       88.5     118.75      78.72
# ...

# %%
obj.chkoutlier(descriptive)
# Out:
# (['hsc_p'], ['hsc_p', 'degree_p', 'salary'])
